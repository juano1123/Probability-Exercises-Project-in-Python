# %% [markdown]
# # Probability exercises

# %% [markdown]
# ### Exercise 1
#
# Two unbiased dice are thrown once and the total score is observed. Use a simulation to find the estimated probability that the total score is even or greater than 7
#
# We could use a mathematical equation to solve this or we can run the experiment many times, and then count the number of times where the score is even or greater than 7
#
# -Run the experiment 1000 times (roll 2 dice 1000 times, and sum the result)
#
# -Keep track of the number of times that the sum was either greater than 7 or an even number
#
# -Divide the number from step 2 by the number of iterations (1000)

# %%
#import libraries
import random
import numpy as np

#Funtion to roll the dice.
def getProbability(nIterations=1000):
    nCount = 0
    for i in range(nIterations):
        dado1 = random.randint(1,6)
        dado2 = random.randint(1,6)
        suma = dado1 + dado2
        #decide if we should add it to the count:
        if suma % 2 == 0 or suma > 7 :
            nCount+= 1
    return nCount/nIterations
print('The probability of rolling an even number or greater than 7 is:', np.round(getProbability()*100, 2), '%')
# Out:
# The probability of rolling an even number or greater than 7 is: 67.5 %

# %% [markdown]
# ### Exercise 2
#
# A box contains 10 white balls, 20 reds and 30 greens. Draw 5 balls with replacement. What is the probability that:
#
# a. 3 white or 2 red
#
# b. All 5 are the same color
#
#
# We will use the same system here. We will pick our balls during each round and count the number of times that:
#
# a. 3 white or 2 red
#
# b. All 5 are the same color.

# %%
#import libraries

d = {}

for i in range(60):
    if i < 10:
        d[i] = 'White'
    elif i > 9 and i < 30:
        d[i] = 'Red'
    else:
        d[i] = 'Green'  
  
        
#Initialize important variables
nSimulations = 1000
partA = 0 
partB = 0

for i in range(nSimulations):
    lista = []
    #make a list of the colors that we choose
    for i in range(5):
        lista.append(d[random.randint(0,59)])
    #Convert it to a numpy array
    lista = np.array(lista)
    #find the number of each taht we picked
    nCountWhite = sum(lista == "White")
    nCountRed = sum(lista == "Red")
    nCountGreen = sum(lista == "Green")
    #Keep track if the combination met the criteria
    if nCountWhite == 3 and nCountRed == 2:
        partA += 1
    if nCountWhite == 5 or nCountRed == 5 or nCountGreen == 5:
        partB += 1

#print 'the probability of 3 white and 2 red is' in percentage
print('The probability of 3 white and 2 red is:', round(partA/nSimulations*100,2),'%')
#print 'the probability of all the same color is' in percentage
print('The probability of all the same color is:', round(partB/nSimulations*100,2),'%')
# Out:
# The probability of 3 white and 2 red is: 0.4 %
# The probability of all the same color is: 2.8 %
